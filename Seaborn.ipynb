# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelojr14/dashboard-vendas/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid", palette="muted")

np.random.seed(101)
n = 300

dados = {
    'idade': np.random.normal(35, 10, n).astype(int),
    'plano': np.random.choice(
        ['Gratuito', 'Básico', 'Pro'],
        n,
        p=[0.5, 0.3, 0.2]
    ),
    'tempo_uso_horas': np.random.uniform(1, 50, n),
    'bugs_reportados': np.random.poisson(2, n),
    'satisfacao': np.random.randint(1, 11, n)
}

df_sistema = pd.DataFrame(dados)

df_sistema.loc[
    df_sistema['plano'] == 'Pro',
    'tempo_uso_horas'
] += 15

df_sistema.loc[
    df_sistema['plano'] == 'Pro',
    'satisfacao'
] += 2

df_sistema['satisfacao'] = (
    df_sistema['satisfacao']
    - (df_sistema['bugs_reportados'] * 0.5)
)

df_sistema['satisfacao'] = (
    df_sistema['satisfacao']
    .clip(1, 10)
    .astype(int)
)

df_sistema['idade'] = df_sistema['idade'].clip(18, 70)

ordem_planos = df_sistema['plano'].value_counts().index

plt.figure(figsize=(8, 5))
sns.countplot(
    data=df_sistema,
    x='plano',
    order=ordem_planos
)
plt.title('Contagem de Usuários por Plano')
plt.xlabel('Plano')
plt.ylabel('Quantidade de Usuários')
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(
    data=df_sistema,
    x='idade',
    kde=True
)
plt.title('Distribuição da Idade dos Usuários')
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.show()

plt.figure(figsize=(8, 5))
sns.boxplot(
    data=df_sistema,
    x='plano',
    y='tempo_uso_horas'
)
plt.title('Tempo de Uso por Plano')
plt.xlabel('Plano')
plt.ylabel('Tempo de Uso (horas)')
plt.show()

plt.figure(figsize=(8, 5))
sns.violinplot(
    data=df_sistema,
    x='plano',
    y='satisfacao'
)
plt.title('Distribuição da Satisfação por Plano')
plt.xlabel('Plano')
plt.ylabel('Satisfação')
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df_sistema,
    x='tempo_uso_horas',
    y='satisfacao',
    hue='plano',
    size='bugs_reportados',
    sizes=(30, 200),
    alpha=0.7
)
plt.title('Relação entre Tempo de Uso e Satisfação')
plt.xlabel('Tempo de Uso (horas)')
plt.ylabel('Satisfação')
plt.show()

variaveis_numericas = df_sistema.select_dtypes(
    include=np.number
)

correlacao = variaveis_numericas.corr(
    method='pearson'
)

plt.figure(figsize=(9, 7))
sns.heatmap(
    correlacao,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    center=0
)
plt.title('Matriz de Correlação de Pearson')
plt.show()

sns.pairplot(
    df_sistema[
        [
            'tempo_uso_horas',
            'bugs_reportados',
            'satisfacao',
            'plano'
        ]
    ],
    hue='plano'
)

plt.show()

print('DataFrame criado com sucesso:')
print(df_sistema.head())

print('\nMatriz de correlação:')
print(correlacao)
# Out:
# DataFrame criado com sucesso:
#    idade     plano  tempo_uso_horas  bugs_reportados  satisfacao
# 0     62  Gratuito        14.165127                3           1
# 1     41    Básico        19.076874                1           2
# 2     44    Básico        28.574818                3           6
# 3     40  Gratuito        28.898728                3           6
# 4     41    Básico         6.566953                1           2
#
# Matriz de correlação:
#                     idade  tempo_uso_horas  bugs_reportados  satisfacao
# idade            1.000000        -0.041905         0.059112   -0.046303
# tempo_uso_horas -0.041905         1.000000        -0.034809    0.081600
# bugs_reportados  0.059112        -0.034809         1.000000   -0.219174
# satisfacao      -0.046303         0.081600        -0.219174    1.000000
